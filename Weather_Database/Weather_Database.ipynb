# %%
# Import dependencies 
import pandas as pd
import requests
import numpy as np
from datetime import datetime
from citipy import citipy 
from config import openweather_api_key

# %%
# Use np.random.uniform with -90,90 and -180,180. Use Size 2000
# Create a set of random latitude and longitude combinations. we pair them together with zip to create tuple
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# use citipy to find the closest cities from our lat_lng tuples
# create cities list to store the cities
cities = []
# for loop to loop through the coordinates in lat_lngs
for coordinates in lat_lngs:
    city = citipy.nearest_city(coordinates[0], coordinates[1]).city_name
    # account for duplicate cities from random lat_lngs by using if 
    if city not in cities:
        cities.append(city)
# check the length of cities list
print(len(cities))
# Out:
# 783

# %%
# now we want to go to api and grab information lat,lng,humidity,cloudiness,windspeed,weather desc
# syntax: api.openweathermap.org/data/2.5/weather?q={city name}&appid={API key}
api_key = openweather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?"
# we want to use fahrenheit 
units = "imperial"

# %%
# create an empty list to add in weather data and create print statement before to show logging
city_data = []
# print logging
print("Beggining Data Retrieval     ")
print("-----------------------------")

# create counters so we can group in sets of 50 to log process as we find weather data for each city (from 1 to 50)
record_count = 1
set_count = 1

# use for city,i in enumerate (cities) to start looping and finding the information of each cities in the list
for i, city in enumerate(cities):
    # start the counter to start grouping in set of 50's
    if i % 50 == 0 & i >= 5:
        set_count +=1
        record_count = 1
    # Create endpoint URL with each city. # when using fstrings, make sure you are not using the same quotes inside as out
    # this is to search if the city has 2 part name, this will use 2 parts to search
    city_url = f"{url}appid={api_key}&q={city.replace(' ', '+')}&units={units}"
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# create try exception to catch if cities not found
# Run an API request for each of the cities.
    try: 
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_description = city_weather["weather"][0]["description"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beggining Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | riyadh
# Processing Record 2 of Set 1 | nizhnevartovsk
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | coihaique
# Processing Record 5 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 1 | anadyr
# Processing Record 7 of Set 1 | chokurdakh
# Processing Record 8 of Set 1 | pokhara
# Processing Record 9 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | provideniya
# Processing Record 12 of Set 1 | east london
# Processing Record 13 of Set 1 | chuy
# Processing Record 14 of Set 1 | khormuj
# City not found. Skipping...
# Processing Record 15 of Set 1 | huarmey
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | taitung
# Processing Record 19 of Set 1 | alikovo
# Processing Record 20 of Set 1 | acari
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | saint george
# Processing Record 24 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 1 | tasiilaq
# Processing Record 26 of Set 1 | gastello
# Processing Record 27 of Set 1 | buta
# Processing Record 28 of Set 1 | moultrie
# Processing Record 29 of Set 1 | khatanga
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | shahrud
# Processing Record 32 of Set 1 | biak
# Processing Record 33 of Set 1 | geraldton
# Processing Record 34 of Set 1 | airai
# Processing Record 35 of Set 1 | grindavik
# Processing Record 36 of Set 1 | kenai
# Processing Record 37 of Set 1 | port keats
# Processing Record 38 of Set 1 | new norfolk
# Processing Record 39 of Set 1 | armacao dos buzios
# City not found. Skipping...
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | cherskiy
# Processing Record 42 of Set 1 | pevek
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | moose factory
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | ponta do sol
# Processing Record 47 of Set 1 | acarau
# Processing Record 48 of Set 1 | itoman
# Processing Record 49 of Set 1 | lebu
# Processing Record 50 of Set 1 | martin
# Processing Record 51 of Set 1 | arraial do cabo
# Processing Record 52 of Set 1 | kapaa
# Processing Record 53 of Set 1 | atuona
# Processing Record 54 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 55 of Set 1 | deputatskiy
# Processing Record 56 of Set 1 | chapais
# Processing Record 57 of Set 1 | molina
# Processing Record 58 of Set 1 | alice springs
# Processing Record 59 of Set 1 | cabatuan
# Processing Record 60 of Set 1 | tuktoyaktuk
# Processing Record 61 of Set 1 | ciudad bolivar
# Processing Record 62 of Set 1 | klaksvik
# Processing Record 63 of Set 1 | barrow
# Processing Record 64 of Set 1 | santa marinella
# Processing Record 65 of Set 1 | bluff
# Processing Record 66 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 67 of Set 1 | mezen
# Processing Record 68 of Set 1 | saskylakh
# Processing Record 69 of Set 1 | yoichi
# Processing Record 70 of Set 1 | safaqis
# City not found. Skipping...
# Processing Record 71 of Set 1 | coquimbo
# Processing Record 72 of Set 1 | salalah
# Processing Record 73 of Set 1 | setermoen
# Processing Record 74 of Set 1 | saint-philippe
# Processing Record 75 of Set 1 | celestun
# Processing Record 76 of Set 1 | port alfred
# Processing Record 77 of Set 1 | punta arenas
# Processing Record 78 of Set 1 | muisne
# Processing Record 79 of Set 1 | kaitangata
# Processing Record 80 of Set 1 | hermanus
# Processing Record 81 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 82 of Set 1 | san rafael
# Processing Record 83 of Set 1 | ajdabiya
# Processing Record 84 of Set 1 | buqayq
# City not found. Skipping...
# Processing Record 85 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 86 of Set 1 | ribeira grande
# Processing Record 87 of Set 1 | bredasdorp
# Processing Record 88 of Set 1 | san patricio
# Processing Record 89 of Set 1 | cape town
# Processing Record 90 of Set 1 | jamestown
# Processing Record 91 of Set 1 | sao borja
# Processing Record 92 of Set 1 | georgetown
# Processing Record 93 of Set 1 | arawa
# Processing Record 94 of Set 1 | hilo
# Processing Record 95 of Set 1 | bambous virieux
# Processing Record 96 of Set 1 | cairns
# Processing Record 97 of Set 1 | trapani
# Processing Record 98 of Set 1 | ulladulla
# Processing Record 99 of Set 1 | bethel
# Processing Record 100 of Set 1 | tiarei
# Processing Record 101 of Set 1 | arcata
# Processing Record 102 of Set 1 | puerto escondido
# Processing Record 103 of Set 1 | afmadu
# City not found. Skipping...
# Processing Record 104 of Set 1 | qaanaaq
# Processing Record 105 of Set 1 | sur
# Processing Record 106 of Set 1 | morondava
# Processing Record 107 of Set 1 | kerema
# Processing Record 108 of Set 1 | lakatoro
# Processing Record 109 of Set 1 | mar del plata
# Processing Record 110 of Set 1 | wawa
# Processing Record 111 of Set 1 | saldanha
# Processing Record 112 of Set 1 | kidal
# Processing Record 113 of Set 1 | aden
# Processing Record 114 of Set 1 | kiomboi
# Processing Record 115 of Set 1 | codrington
# Processing Record 116 of Set 1 | manokwari
# Processing Record 117 of Set 1 | port elizabeth
# Processing Record 118 of Set 1 | clyde river
# Processing Record 119 of Set 1 | kontagora
# Processing Record 120 of Set 1 | avarua
# Processing Record 121 of Set 1 | penzance
# Processing Record 122 of Set 1 | zhanaozen
# Processing Record 123 of Set 1 | aksu
# Processing Record 124 of Set 1 | montijo
# Processing Record 125 of Set 1 | cabo san lucas
# Processing Record 126 of Set 1 | zhezkazgan
# Processing Record 127 of Set 1 | hovd
# Processing Record 128 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 129 of Set 1 | binzhou
# Processing Record 130 of Set 1 | nuevitas
# Processing Record 131 of Set 1 | basco
# Processing Record 132 of Set 1 | alofi
# Processing Record 133 of Set 1 | victoria
# Processing Record 134 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 135 of Set 1 | tual
# Processing Record 136 of Set 1 | college
# Processing Record 137 of Set 1 | kashi
# Processing Record 138 of Set 1 | thompson
# Processing Record 139 of Set 1 | dakar
# Processing Record 140 of Set 1 | samarai
# Processing Record 141 of Set 1 | castro
# Processing Record 142 of Set 1 | yinchuan
# Processing Record 143 of Set 1 | santa rosalia
# Processing Record 144 of Set 1 | pytalovo
# Processing Record 145 of Set 1 | narsaq
# Processing Record 146 of Set 1 | sabang
# Processing Record 147 of Set 1 | izhma
# Processing Record 148 of Set 1 | bubaque
# Processing Record 149 of Set 1 | beisfjord
# Processing Record 150 of Set 1 | faya
# Processing Record 151 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 152 of Set 1 | porosozero
# Processing Record 153 of Set 1 | malmyzh
# Processing Record 154 of Set 1 | henties bay
# Processing Record 155 of Set 1 | marzuq
# Processing Record 156 of Set 1 | badhni kalan
# Processing Record 157 of Set 1 | imeni poliny osipenko
# Processing Record 158 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 159 of Set 1 | fukue
# Processing Record 160 of Set 1 | qaqortoq
# Processing Record 161 of Set 1 | axim
# Processing Record 162 of Set 1 | fuyang
# Processing Record 163 of Set 1 | kardla
# Processing Record 164 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 165 of Set 1 | tara
# Processing Record 166 of Set 1 | ozernovskiy
# Processing Record 167 of Set 1 | honiara
# Processing Record 168 of Set 1 | boende
# Processing Record 169 of Set 1 | bichura
# Processing Record 170 of Set 1 | bengkulu
# Processing Record 171 of Set 1 | ilinskiy
# Processing Record 172 of Set 1 | omboue
# Processing Record 173 of Set 1 | atar
# Processing Record 174 of Set 1 | vieux-habitants
# Processing Record 175 of Set 1 | bitlis
# Processing Record 176 of Set 1 | lincoln
# Processing Record 177 of Set 1 | sisimiut
# Processing Record 178 of Set 1 | bartica
# Processing Record 179 of Set 1 | cabedelo
# Processing Record 180 of Set 1 | sarospatak
# Processing Record 181 of Set 1 | azimur
# City not found. Skipping...
# Processing Record 182 of Set 1 | san carlos de bariloche
# Processing Record 183 of Set 1 | valparaiso
# Processing Record 184 of Set 1 | cayambe
# Processing Record 185 of Set 1 | muros
# Processing Record 186 of Set 1 | tilichiki
# Processing Record 187 of Set 1 | griffith
# Processing Record 188 of Set 1 | haines junction
# Processing Record 189 of Set 1 | poum
# Processing Record 190 of Set 1 | saint anthony
# Processing Record 191 of Set 1 | longyearbyen
# Processing Record 192 of Set 1 | husavik
# Processing Record 193 of Set 1 | gizo
# Processing Record 194 of Set 1 | shubarkuduk
# Processing Record 195 of Set 1 | douentza
# Processing Record 196 of Set 1 | butaritari
# Processing Record 197 of Set 1 | menzelinsk
# Processing Record 198 of Set 1 | caldwell
# Processing Record 199 of Set 1 | cidreira
# Processing Record 200 of Set 1 | maturin
# Processing Record 201 of Set 1 | morro bay
# Processing Record 202 of Set 1 | ituni
# City not found. Skipping...
# Processing Record 203 of Set 1 | altamira
# Processing Record 204 of Set 1 | batagay-alyta
# Processing Record 205 of Set 1 | srednekolymsk
# Processing Record 206 of Set 1 | shipitsyno
# Processing Record 207 of Set 1 | north bend
# Processing Record 208 of Set 1 | kununurra
# Processing Record 209 of Set 1 | port shepstone
# Processing Record 210 of Set 1 | jiazi
# Processing Record 211 of Set 1 | cayenne
# Processing Record 212 of Set 1 | trairi
# Processing Record 213 of Set 1 | leningradskiy
# Processing Record 214 of Set 1 | homer
# Processing Record 215 of Set 1 | zhigansk
# Processing Record 216 of Set 1 | mnogovershinnyy
# Processing Record 217 of Set 1 | okha
# Processing Record 218 of Set 1 | oistins
# Processing Record 219 of Set 1 | obo
# Processing Record 220 of Set 1 | tecoanapa
# Processing Record 221 of Set 1 | boguchany
# Processing Record 222 of Set 1 | vestmannaeyjar
# Processing Record 223 of Set 1 | tiksi
# Processing Record 224 of Set 1 | amapa
# Processing Record 225 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 226 of Set 1 | korla
# Processing Record 227 of Set 1 | eura
# Processing Record 228 of Set 1 | kaduy
# Processing Record 229 of Set 1 | vanimo
# Processing Record 230 of Set 1 | tadine
# Processing Record 231 of Set 1 | ayorou
# Processing Record 232 of Set 1 | ust-kuyga
# Processing Record 233 of Set 1 | zyryanka
# Processing Record 234 of Set 1 | broken hill
# Processing Record 235 of Set 1 | shingu
# Processing Record 236 of Set 1 | kodiak
# Processing Record 237 of Set 1 | karakol
# Processing Record 238 of Set 1 | wajir
# Processing Record 239 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 240 of Set 1 | vardo
# Processing Record 241 of Set 1 | zachagansk
# City not found. Skipping...
# Processing Record 242 of Set 1 | sinnamary
# Processing Record 243 of Set 1 | nago
# Processing Record 244 of Set 1 | muncar
# Processing Record 245 of Set 1 | ilulissat
# Processing Record 246 of Set 1 | buritama
# Processing Record 247 of Set 1 | bodden town
# Processing Record 248 of Set 1 | estelle
# Processing Record 249 of Set 1 | skiros
# City not found. Skipping...
# Processing Record 250 of Set 1 | wangaratta
# Processing Record 251 of Set 1 | kieta
# Processing Record 252 of Set 1 | mount gambier
# Processing Record 253 of Set 1 | dubbo
# Processing Record 254 of Set 1 | lompoc
# Processing Record 255 of Set 1 | jijiga
# Processing Record 256 of Set 1 | dryden
# Processing Record 257 of Set 1 | lethem
# Processing Record 258 of Set 1 | touros
# Processing Record 259 of Set 1 | sant feliu de guixols
# Processing Record 260 of Set 1 | fort nelson
# Processing Record 261 of Set 1 | lubango
# Processing Record 262 of Set 1 | guerrero
# Processing Record 263 of Set 1 | merauke
# Processing Record 264 of Set 1 | fairbanks
# Processing Record 265 of Set 1 | carballo
# Processing Record 266 of Set 1 | staryy nadym
# Processing Record 267 of Set 1 | espanola
# Processing Record 268 of Set 1 | methoni
# Processing Record 269 of Set 1 | upernavik
# Processing Record 270 of Set 1 | genhe
# Processing Record 271 of Set 1 | aripuana
# Processing Record 272 of Set 1 | caravelas
# Processing Record 273 of Set 1 | bandarbeyla
# Processing Record 274 of Set 1 | tanete
# Processing Record 275 of Set 1 | dikson
# Processing Record 276 of Set 1 | kavieng
# Processing Record 277 of Set 1 | rawson
# Processing Record 278 of Set 1 | beyneu
# Processing Record 279 of Set 1 | manicore
# Processing Record 280 of Set 1 | da lat
# Processing Record 281 of Set 1 | hammerfest
# Processing Record 282 of Set 1 | katha
# City not found. Skipping...
# Processing Record 283 of Set 1 | nanortalik
# Processing Record 284 of Set 1 | umm lajj
# Processing Record 285 of Set 1 | hirara
# Processing Record 286 of Set 1 | forrest city
# Processing Record 287 of Set 1 | pochutla
# Processing Record 288 of Set 1 | salaspils
# Processing Record 289 of Set 1 | sao joao da barra
# Processing Record 290 of Set 1 | kilindoni
# Processing Record 291 of Set 1 | piacabucu
# Processing Record 292 of Set 1 | westport
# Processing Record 293 of Set 1 | mercedes
# Processing Record 294 of Set 1 | amahai
# Processing Record 295 of Set 1 | matias romero
# Processing Record 296 of Set 1 | port blair
# Processing Record 297 of Set 1 | athabasca
# Processing Record 298 of Set 1 | auki
# Processing Record 299 of Set 1 | bouafle
# Processing Record 300 of Set 1 | vostok
# Processing Record 301 of Set 1 | ondangwa
# Processing Record 302 of Set 1 | chicama
# Processing Record 303 of Set 1 | port hedland
# Processing Record 304 of Set 1 | talnakh
# Processing Record 305 of Set 1 | florence
# Processing Record 306 of Set 1 | finschhafen
# Processing Record 307 of Set 1 | solnechnyy
# Processing Record 308 of Set 1 | alcacer do sal
# Processing Record 309 of Set 1 | luderitz
# Processing Record 310 of Set 1 | viedma
# Processing Record 311 of Set 1 | carnarvon
# Processing Record 312 of Set 1 | tabou
# Processing Record 313 of Set 1 | nador
# Processing Record 314 of Set 1 | juegang
# Processing Record 315 of Set 1 | dombarovskiy
# Processing Record 316 of Set 1 | yulara
# Processing Record 317 of Set 1 | dongying
# Processing Record 318 of Set 1 | namatanai
# Processing Record 319 of Set 1 | mokhsogollokh
# Processing Record 320 of Set 1 | sinjar
# Processing Record 321 of Set 1 | yushu
# Processing Record 322 of Set 1 | jumla
# Processing Record 323 of Set 1 | vao
# Processing Record 324 of Set 1 | ostrovnoy
# Processing Record 325 of Set 1 | toledo
# Processing Record 326 of Set 1 | nhulunbuy
# Processing Record 327 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 328 of Set 1 | sept-iles
# Processing Record 329 of Set 1 | soverato
# Processing Record 330 of Set 1 | hoi an
# Processing Record 331 of Set 1 | puerto ayora
# Processing Record 332 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 333 of Set 1 | george town
# Processing Record 334 of Set 1 | lar gerd
# City not found. Skipping...
# Processing Record 335 of Set 1 | navahrudak
# Processing Record 336 of Set 1 | alamosa
# Processing Record 337 of Set 1 | palu
# Processing Record 338 of Set 1 | la ronge
# Processing Record 339 of Set 1 | naryan-mar
# Processing Record 340 of Set 1 | gombe
# Processing Record 341 of Set 1 | ratangarh
# Processing Record 342 of Set 1 | zhanakorgan
# Processing Record 343 of Set 1 | arkadak
# Processing Record 344 of Set 1 | conakry
# Processing Record 345 of Set 1 | hasaki
# Processing Record 346 of Set 1 | andenes
# Processing Record 347 of Set 1 | razole
# Processing Record 348 of Set 1 | duz
# City not found. Skipping...
# Processing Record 349 of Set 1 | houma
# Processing Record 350 of Set 1 | port-gentil
# Processing Record 351 of Set 1 | kondinskoye
# Processing Record 352 of Set 1 | kavaratti
# Processing Record 353 of Set 1 | taoudenni
# Processing Record 354 of Set 1 | abengourou
# Processing Record 355 of Set 1 | gavle
# Processing Record 356 of Set 1 | ginir
# Processing Record 357 of Set 1 | iqaluit
# Processing Record 358 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 359 of Set 1 | shache
# Processing Record 360 of Set 1 | gulbarga
# Processing Record 361 of Set 1 | utete
# Processing Record 362 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 363 of Set 1 | grand-santi
# Processing Record 364 of Set 1 | saint-georges
# Processing Record 365 of Set 1 | lewiston
# Processing Record 366 of Set 1 | souillac
# Processing Record 367 of Set 1 | richards bay
# Processing Record 368 of Set 1 | kurumkan
# Processing Record 369 of Set 1 | olafsvik
# Processing Record 370 of Set 1 | labuhan
# Processing Record 371 of Set 1 | shimoda
# Processing Record 372 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 373 of Set 1 | abonnema
# Processing Record 374 of Set 1 | mandalgovi
# Processing Record 375 of Set 1 | surt
# Processing Record 376 of Set 1 | ahuimanu
# Processing Record 377 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 378 of Set 1 | sitka
# Processing Record 379 of Set 1 | norman wells
# Processing Record 380 of Set 1 | lahan
# Processing Record 381 of Set 1 | brae
# Processing Record 382 of Set 1 | pitimbu
# Processing Record 383 of Set 1 | gaoua
# Processing Record 384 of Set 1 | ouadda
# Processing Record 385 of Set 1 | schaffhausen
# Processing Record 386 of Set 1 | simbahan
# Processing Record 387 of Set 1 | meulaboh
# Processing Record 388 of Set 1 | soller
# Processing Record 389 of Set 1 | lorengau
# Processing Record 390 of Set 1 | yar-sale
# Processing Record 391 of Set 1 | kahului
# Processing Record 392 of Set 1 | katobu
# Processing Record 393 of Set 1 | esna
# Processing Record 394 of Set 1 | birjand
# Processing Record 395 of Set 1 | comodoro rivadavia
# Processing Record 396 of Set 1 | pilar
# Processing Record 397 of Set 1 | linares
# Processing Record 398 of Set 1 | sibolga
# Processing Record 399 of Set 1 | presidencia roque saenz pena
# Processing Record 400 of Set 1 | barra patuca
# Processing Record 401 of Set 1 | ampanihy
# Processing Record 402 of Set 1 | vila franca do campo
# Processing Record 403 of Set 1 | mocuba
# Processing Record 404 of Set 1 | plettenberg bay
# Processing Record 405 of Set 1 | yasnyy
# Processing Record 406 of Set 1 | beringovskiy
# Processing Record 407 of Set 1 | saint-pierre
# Processing Record 408 of Set 1 | gubkinskiy
# Processing Record 409 of Set 1 | asfi
# Processing Record 410 of Set 1 | yumen
# Processing Record 411 of Set 1 | save
# Processing Record 412 of Set 1 | fakel
# Processing Record 413 of Set 1 | dondo
# Processing Record 414 of Set 1 | zaterechnyy
# Processing Record 415 of Set 1 | kuching
# Processing Record 416 of Set 1 | ifakara
# Processing Record 417 of Set 1 | aklavik
# Processing Record 418 of Set 1 | radcliff
# Processing Record 419 of Set 1 | chumphon
# Processing Record 420 of Set 1 | betsiamites
# Processing Record 421 of Set 1 | kijang
# Processing Record 422 of Set 1 | ucluelet
# Processing Record 423 of Set 1 | cambridge
# Processing Record 424 of Set 1 | khorixas
# Processing Record 425 of Set 1 | kommunisticheskiy
# Processing Record 426 of Set 1 | mahebourg
# Processing Record 427 of Set 1 | nantucket
# Processing Record 428 of Set 1 | terre-de-bas
# Processing Record 429 of Set 1 | chester
# Processing Record 430 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 431 of Set 1 | ugoofaaru
# Processing Record 432 of Set 1 | goias
# Processing Record 433 of Set 1 | kruisfontein
# Processing Record 434 of Set 1 | roma
# Processing Record 435 of Set 1 | blagoyevo
# Processing Record 436 of Set 1 | goderich
# Processing Record 437 of Set 1 | beloha
# Processing Record 438 of Set 1 | kostomuksha
# Processing Record 439 of Set 1 | tarakan
# Processing Record 440 of Set 1 | maniitsoq
# Processing Record 441 of Set 1 | ryotsu
# Processing Record 442 of Set 1 | ruatoria
# City not found. Skipping...
# Processing Record 443 of Set 1 | bemidji
# Processing Record 444 of Set 1 | mildura
# Processing Record 445 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 446 of Set 1 | pacific grove
# Processing Record 447 of Set 1 | ahipara
# Processing Record 448 of Set 1 | labuan
# Processing Record 449 of Set 1 | etaples
# Processing Record 450 of Set 1 | lawrenceburg
# Processing Record 451 of Set 1 | villa maria
# Processing Record 452 of Set 1 | bonito
# Processing Record 453 of Set 1 | khandyga
# Processing Record 454 of Set 1 | esperance
# Processing Record 455 of Set 1 | belmonte
# Processing Record 456 of Set 1 | asau
# Processing Record 457 of Set 1 | breaza
# Processing Record 458 of Set 1 | suntar
# Processing Record 459 of Set 1 | rey bouba
# Processing Record 460 of Set 1 | kerman
# Processing Record 461 of Set 1 | kirakira
# Processing Record 462 of Set 1 | towada
# Processing Record 463 of Set 1 | tuatapere
# Processing Record 464 of Set 1 | thongwa
# Processing Record 465 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 466 of Set 1 | mayor pablo lagerenza
# Processing Record 467 of Set 1 | jiblah
# Processing Record 468 of Set 1 | constitucion
# Processing Record 469 of Set 1 | pisco
# Processing Record 470 of Set 1 | severo-kurilsk
# Processing Record 471 of Set 1 | kamenka
# Processing Record 472 of Set 1 | caceres
# Processing Record 473 of Set 1 | sao felix do xingu
# Processing Record 474 of Set 1 | kiama
# Processing Record 475 of Set 1 | kysyl-syr
# Processing Record 476 of Set 1 | shemursha
# Processing Record 477 of Set 1 | darhan
# Processing Record 478 of Set 1 | banda aceh
# Processing Record 479 of Set 1 | guerrero negro
# Processing Record 480 of Set 1 | dhidhdhoo
# Processing Record 481 of Set 1 | port-de-bouc
# Processing Record 482 of Set 1 | micheweni
# Processing Record 483 of Set 1 | hervey bay
# Processing Record 484 of Set 1 | provost
# Processing Record 485 of Set 1 | albanel
# Processing Record 486 of Set 1 | paamiut
# Processing Record 487 of Set 1 | margate
# Processing Record 488 of Set 1 | loa janan
# Processing Record 489 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 490 of Set 1 | agadez
# Processing Record 491 of Set 1 | moa
# Processing Record 492 of Set 1 | cloquet
# Processing Record 493 of Set 1 | saint-augustin
# Processing Record 494 of Set 1 | marawi
# Processing Record 495 of Set 1 | portland
# Processing Record 496 of Set 1 | nicoya
# Processing Record 497 of Set 1 | broome
# Processing Record 498 of Set 1 | usolye
# Processing Record 499 of Set 1 | torbay
# Processing Record 500 of Set 1 | magadan
# Processing Record 501 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 502 of Set 1 | butembo
# Processing Record 503 of Set 1 | laguna
# Processing Record 504 of Set 1 | siena
# Processing Record 505 of Set 1 | koygorodok
# Processing Record 506 of Set 1 | te anau
# Processing Record 507 of Set 1 | hobyo
# Processing Record 508 of Set 1 | ponta delgada
# Processing Record 509 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 510 of Set 1 | krasnoarmeyskiy
# Processing Record 511 of Set 1 | dingle
# Processing Record 512 of Set 1 | namibe
# Processing Record 513 of Set 1 | port lincoln
# Processing Record 514 of Set 1 | baruun-urt
# Processing Record 515 of Set 1 | leshukonskoye
# Processing Record 516 of Set 1 | zhetybay
# City not found. Skipping...
# Processing Record 517 of Set 1 | fortuna
# Processing Record 518 of Set 1 | conil
# Processing Record 519 of Set 1 | abu dhabi
# Processing Record 520 of Set 1 | shira
# Processing Record 521 of Set 1 | port hardy
# Processing Record 522 of Set 1 | newala
# Processing Record 523 of Set 1 | kurali
# Processing Record 524 of Set 1 | san carlos
# Processing Record 525 of Set 1 | prince rupert
# Processing Record 526 of Set 1 | xingyi
# Processing Record 527 of Set 1 | shinpokh
# Processing Record 528 of Set 1 | pedernales
# Processing Record 529 of Set 1 | naze
# Processing Record 530 of Set 1 | cuamba
# Processing Record 531 of Set 1 | zhuhai
# Processing Record 532 of Set 1 | itarema
# Processing Record 533 of Set 1 | marsh harbour
# Processing Record 534 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 535 of Set 1 | nome
# Processing Record 536 of Set 1 | colesberg
# Processing Record 537 of Set 1 | urumqi
# Processing Record 538 of Set 1 | faanui
# Processing Record 539 of Set 1 | nouakchott
# Processing Record 540 of Set 1 | kralendijk
# Processing Record 541 of Set 1 | chardara
# Processing Record 542 of Set 1 | khandagayty
# Processing Record 543 of Set 1 | yarada
# Processing Record 544 of Set 1 | santa cruz
# Processing Record 545 of Set 1 | masuguru
# Processing Record 546 of Set 1 | ola
# Processing Record 547 of Set 1 | matcha
# Processing Record 548 of Set 1 | tautira
# Processing Record 549 of Set 1 | kuytun
# Processing Record 550 of Set 1 | baghdad
# Processing Record 551 of Set 1 | natal
# Processing Record 552 of Set 1 | buala
# Processing Record 553 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 554 of Set 1 | fatehpur sikri
# Processing Record 555 of Set 1 | gladstone
# Processing Record 556 of Set 1 | bolshiye klyuchishchi
# City not found. Skipping...
# Processing Record 557 of Set 1 | buncrana
# Processing Record 558 of Set 1 | zlynka
# Processing Record 559 of Set 1 | along
# Processing Record 560 of Set 1 | kisangani
# Processing Record 561 of Set 1 | phan thiet
# Processing Record 562 of Set 1 | bairiki
# Processing Record 563 of Set 1 | lagoa
# Processing Record 564 of Set 1 | udachnyy
# Processing Record 565 of Set 1 | traverse city
# Processing Record 566 of Set 1 | berlevag
# Processing Record 567 of Set 1 | mogocha
# Processing Record 568 of Set 1 | krylovskaya
# Processing Record 569 of Set 1 | mwinilunga
# Processing Record 570 of Set 1 | kargil
# Processing Record 571 of Set 1 | shchelkun
# Processing Record 572 of Set 1 | serra talhada
# Processing Record 573 of Set 1 | havre-saint-pierre
# Processing Record 574 of Set 1 | edd
# Processing Record 575 of Set 1 | cam ranh
# Processing Record 576 of Set 1 | synya
# Processing Record 577 of Set 1 | codajas
# Processing Record 578 of Set 1 | komsomolskiy
# Processing Record 579 of Set 1 | sao felipe
# Processing Record 580 of Set 1 | san matias
# Processing Record 581 of Set 1 | araouane
# Processing Record 582 of Set 1 | fulton
# Processing Record 583 of Set 1 | geelong
# Processing Record 584 of Set 1 | ustyuzhna
# Processing Record 585 of Set 1 | marystown
# Processing Record 586 of Set 1 | lucapa
# Processing Record 587 of Set 1 | salinopolis
# Processing Record 588 of Set 1 | russell
# Processing Record 589 of Set 1 | kenora
# Processing Record 590 of Set 1 | maldonado
# Processing Record 591 of Set 1 | oskemen
# Processing Record 592 of Set 1 | korhogo
# Processing Record 593 of Set 1 | vila velha
# Processing Record 594 of Set 1 | semey
# Processing Record 595 of Set 1 | bucerias
# Processing Record 596 of Set 1 | the valley
# Processing Record 597 of Set 1 | san pedro de ycuamandiyu
# Processing Record 598 of Set 1 | chaska
# Processing Record 599 of Set 1 | bouca
# Processing Record 600 of Set 1 | manoel urbano
# Processing Record 601 of Set 1 | lyubashivka
# Processing Record 602 of Set 1 | ligayan
# Processing Record 603 of Set 1 | nkayi
# Processing Record 604 of Set 1 | teknaf
# Processing Record 605 of Set 1 | nemuro
# Processing Record 606 of Set 1 | lafia
# Processing Record 607 of Set 1 | amuntai
# Processing Record 608 of Set 1 | yaval
# Processing Record 609 of Set 1 | kamaishi
# Processing Record 610 of Set 1 | luanda
# Processing Record 611 of Set 1 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 612 of Set 1 | cascais
# Processing Record 613 of Set 1 | great yarmouth
# Processing Record 614 of Set 1 | lindsay
# Processing Record 615 of Set 1 | zavyalovo
# Processing Record 616 of Set 1 | whitehorse
# Processing Record 617 of Set 1 | poopo
# Processing Record 618 of Set 1 | port moresby
# Processing Record 619 of Set 1 | elizabeth city
# Processing Record 620 of Set 1 | quimper
# Processing Record 621 of Set 1 | kutum
# Processing Record 622 of Set 1 | lavrentiya
# Processing Record 623 of Set 1 | falmouth
# Processing Record 624 of Set 1 | barmer
# Processing Record 625 of Set 1 | mormugao
# Processing Record 626 of Set 1 | starkville
# Processing Record 627 of Set 1 | dashitou
# Processing Record 628 of Set 1 | kloulklubed
# Processing Record 629 of Set 1 | lufkin
# Processing Record 630 of Set 1 | acapulco
# Processing Record 631 of Set 1 | walvis bay
# Processing Record 632 of Set 1 | prainha
# Processing Record 633 of Set 1 | baykit
# Processing Record 634 of Set 1 | champerico
# Processing Record 635 of Set 1 | soc trang
# Processing Record 636 of Set 1 | ixtapa
# Processing Record 637 of Set 1 | fallon
# Processing Record 638 of Set 1 | plougastel-daoulas
# Processing Record 639 of Set 1 | videira
# Processing Record 640 of Set 1 | tete
# Processing Record 641 of Set 1 | ust-omchug
# Processing Record 642 of Set 1 | bonfim
# Processing Record 643 of Set 1 | padang
# Processing Record 644 of Set 1 | reidsville
# Processing Record 645 of Set 1 | sawakin
# Processing Record 646 of Set 1 | hambantota
# Processing Record 647 of Set 1 | winneba
# Processing Record 648 of Set 1 | majene
# Processing Record 649 of Set 1 | los llanos de aridane
# Processing Record 650 of Set 1 | uyuni
# Processing Record 651 of Set 1 | wajima
# Processing Record 652 of Set 1 | bud
# Processing Record 653 of Set 1 | racalmuto
# Processing Record 654 of Set 1 | neyvo-shaytanskiy
# Processing Record 655 of Set 1 | wanderlandia
# City not found. Skipping...
# Processing Record 656 of Set 1 | atasu
# Processing Record 657 of Set 1 | grajau
# Processing Record 658 of Set 1 | wahiawa
# Processing Record 659 of Set 1 | guymon
# Processing Record 660 of Set 1 | kargasok
# Processing Record 661 of Set 1 | davidson
# Processing Record 662 of Set 1 | ziro
# Processing Record 663 of Set 1 | magistralnyy
# Processing Record 664 of Set 1 | adrar
# Processing Record 665 of Set 1 | mandiana
# Processing Record 666 of Set 1 | springbok
# Processing Record 667 of Set 1 | vangaindrano
# Processing Record 668 of Set 1 | wyndham
# Processing Record 669 of Set 1 | paraiso
# Processing Record 670 of Set 1 | pontianak
# Processing Record 671 of Set 1 | wanning
# Processing Record 672 of Set 1 | mount isa
# Processing Record 673 of Set 1 | ta khmau
# Processing Record 674 of Set 1 | turbat
# Processing Record 675 of Set 1 | charters towers
# Processing Record 676 of Set 1 | plock
# Processing Record 677 of Set 1 | mykhaylivka
# Processing Record 678 of Set 1 | wladyslawowo
# Processing Record 679 of Set 1 | skalistyy
# City not found. Skipping...
# Processing Record 680 of Set 1 | pyaozerskiy
# Processing Record 681 of Set 1 | katsuura
# Processing Record 682 of Set 1 | hofn
# Processing Record 683 of Set 1 | banikoara
# Processing Record 684 of Set 1 | santiago
# Processing Record 685 of Set 1 | shkotovo-26
# City not found. Skipping...
# Processing Record 686 of Set 1 | fort morgan
# Processing Record 687 of Set 1 | kangaatsiaq
# Processing Record 688 of Set 1 | cockburn town
# Processing Record 689 of Set 1 | santa rosa
# Processing Record 690 of Set 1 | fort saint john
# City not found. Skipping...
# Processing Record 691 of Set 1 | neepawa
# Processing Record 692 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 693 of Set 1 | ankang
# Processing Record 694 of Set 1 | yatou
# Processing Record 695 of Set 1 | mandali
# Processing Record 696 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 697 of Set 1 | bogatyye saby
# Processing Record 698 of Set 1 | whittlesea
# Processing Record 699 of Set 1 | pangkalanbuun
# Processing Record 700 of Set 1 | dolbeau
# City not found. Skipping...
# Processing Record 701 of Set 1 | wad madani
# Processing Record 702 of Set 1 | esterhazy
# Processing Record 703 of Set 1 | wagar
# Processing Record 704 of Set 1 | chulman
# Processing Record 705 of Set 1 | medicine hat
# Processing Record 706 of Set 1 | bageshwar
# Processing Record 707 of Set 1 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 708 of Set 1 | manzhouli
# Processing Record 709 of Set 1 | bambui
# Processing Record 710 of Set 1 | paracuru
# Processing Record 711 of Set 1 | san martin
# Processing Record 712 of Set 1 | mayumba
# Processing Record 713 of Set 1 | inirida
# Processing Record 714 of Set 1 | skibbereen
# Processing Record 715 of Set 1 | porto novo
# Processing Record 716 of Set 1 | vinh
# Processing Record 717 of Set 1 | diapaga
# Processing Record 718 of Set 1 | vacaria
# Processing Record 719 of Set 1 | bahia honda
# Processing Record 720 of Set 1 | mawlaik
# Processing Record 721 of Set 1 | farafenni
# Processing Record 722 of Set 1 | kota tinggi
# Processing Record 723 of Set 1 | oliveira
# Processing Record 724 of Set 1 | nelson bay
# Processing Record 725 of Set 1 | hami
# Processing Record 726 of Set 1 | malanje
# Processing Record 727 of Set 1 | senanga
# Processing Record 728 of Set 1 | kotovo
# Processing Record 729 of Set 1 | thinadhoo
# Processing Record 730 of Set 1 | alghero
# Processing Record 731 of Set 1 | tura
# Processing Record 732 of Set 1 | kodinsk
# Processing Record 733 of Set 1 | ketchikan
# Processing Record 734 of Set 1 | filadelfia
# Processing Record 735 of Set 1 | quelimane
# Processing Record 736 of Set 1 | hurghada
# Processing Record 737 of Set 1 | kaeo
# Processing Record 738 of Set 1 | aljezur
# Processing Record 739 of Set 1 | davila
# Processing Record 740 of Set 1 | lata
# Processing Record 741 of Set 1 | batticaloa
# Processing Record 742 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 743 of Set 1 | comiso
# Processing Record 744 of Set 1 | ortona
# Processing Record 745 of Set 1 | novikovo
# Processing Record 746 of Set 1 | struer
# Processing Record 747 of Set 1 | progreso
# Processing Record 748 of Set 1 | sungaipenuh
# Processing Record 749 of Set 1 | jaru
# Processing Record 750 of Set 1 | azar shahr
# City not found. Skipping...
# Processing Record 751 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 752 of Set 1 | yerbogachen
# Processing Record 753 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 754 of Set 1 | iquique
# Processing Record 755 of Set 1 | mahibadhoo
# Processing Record 756 of Set 1 | trinidad
# Processing Record 757 of Set 1 | high rock
# Processing Record 758 of Set 1 | karamea
# City not found. Skipping...
# Processing Record 759 of Set 1 | whitley bay
# Processing Record 760 of Set 1 | port macquarie
# Processing Record 761 of Set 1 | gushikawa
# Processing Record 762 of Set 1 | havoysund
# Processing Record 763 of Set 1 | alice town
# Processing Record 764 of Set 1 | cuauhtemoc
# Processing Record 765 of Set 1 | shuangcheng
# Processing Record 766 of Set 1 | acin
# City not found. Skipping...
# Processing Record 767 of Set 1 | cluny
# Processing Record 768 of Set 1 | jinchang
# Processing Record 769 of Set 1 | severomuysk
# Processing Record 770 of Set 1 | takoradi
# Processing Record 771 of Set 1 | qujing
# Processing Record 772 of Set 1 | hamilton
# Processing Record 773 of Set 1 | murgab
# Processing Record 774 of Set 1 | santana do livramento
# Processing Record 775 of Set 1 | point pedro
# Processing Record 776 of Set 1 | mergui
# City not found. Skipping...
# Processing Record 777 of Set 1 | raduzhnyy
# Processing Record 778 of Set 1 | borogontsy
# Processing Record 779 of Set 1 | gambela
# Processing Record 780 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 781 of Set 1 | jacqueville
# Processing Record 782 of Set 1 | buluang
# Processing Record 783 of Set 1 | issoire
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# check how many cities with info are there
print(len(city_data))
# Out:
# 724

# %%
# store into data frame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Riyadh  24.6877   46.7219     87.85        11           0
# 1  Nizhnevartovsk  60.9344   76.5531     68.02        64           0
# 2          Albany  42.6001  -73.9662     68.92        75          80
# 3       Coihaique -45.5752  -72.0662     37.35        65           0
# 4          Anadyr  64.7500  177.4833     50.50        57          75
# 5      Chokurdakh  70.6333  147.9167     64.67        38         100
# 6         Pokhara  28.2333   83.9833     71.74        88         100
# 7          Hobart -42.8794  147.3294     57.02        92          75
# 8     Provideniya  64.3833 -173.3000     36.27        97         100
# 9     East London -33.0153   27.9116     62.64        74          57
#
#    Wind Speed Country                 Date      Description
# 0        9.22      SA  2021-06-14 01:33:52             dust
# 1        6.71      RU  2021-06-14 01:35:04        clear sky
# 2        6.42      US  2021-06-14 01:32:17    broken clouds
# 3        3.44      CL  2021-06-14 01:35:05        clear sky
# 4       13.42      RU  2021-06-14 01:35:05    broken clouds
# 5        5.66      RU  2021-06-14 01:33:35  overcast clouds
# 6        4.12      NP  2021-06-14 01:35:06  overcast clouds
# 7        1.01      AU  2021-06-14 01:30:08    broken clouds
# 8       13.71      RU  2021-06-14 01:33:33       light rain
# 9       12.33      ZA  2021-06-14 01:32:22    broken clouds

# %%
# to change column order, you must declare a list with the new column orders, then pass it through the dataframe and drop date
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Riyadh      SA  24.6877   46.7219     87.85        11           0
# 1  Nizhnevartovsk      RU  60.9344   76.5531     68.02        64           0
# 2          Albany      US  42.6001  -73.9662     68.92        75          80
# 3       Coihaique      CL -45.5752  -72.0662     37.35        65           0
# 4          Anadyr      RU  64.7500  177.4833     50.50        57          75
# 5      Chokurdakh      RU  70.6333  147.9167     64.67        38         100
# 6         Pokhara      NP  28.2333   83.9833     71.74        88         100
# 7          Hobart      AU -42.8794  147.3294     57.02        92          75
# 8     Provideniya      RU  64.3833 -173.3000     36.27        97         100
# 9     East London      ZA -33.0153   27.9116     62.64        74          57
#
#    Wind Speed      Description
# 0        9.22             dust
# 1        6.71        clear sky
# 2        6.42    broken clouds
# 3        3.44        clear sky
# 4       13.42    broken clouds
# 5        5.66  overcast clouds
# 6        4.12  overcast clouds
# 7        1.01    broken clouds
# 8       13.71       light rain
# 9       12.33    broken clouds

# %%
# rename description to current description
renamed_city_data_df = city_data_df.rename(columns= {'Description' : 'Current Description'})
renamed_city_data_df.head(5)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Riyadh      SA  24.6877   46.7219     87.85        11           0
# 1  Nizhnevartovsk      RU  60.9344   76.5531     68.02        64           0
# 2          Albany      US  42.6001  -73.9662     68.92        75          80
# 3       Coihaique      CL -45.5752  -72.0662     37.35        65           0
# 4          Anadyr      RU  64.7500  177.4833     50.50        57          75
#
#    Wind Speed Current Description
# 0        9.22                dust
# 1        6.71           clear sky
# 2        6.42       broken clouds
# 3        3.44           clear sky
# 4       13.42       broken clouds

# %%
# save into csv into Weather_Database folder
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
renamed_city_data_df.to_csv(output_data_file, index_label="City_ID")
